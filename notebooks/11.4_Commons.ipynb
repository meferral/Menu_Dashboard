# %%
import pandas as pd
import re
import datetime as dt

# %%
Nov_4_Comm = pd.read_csv('../netmenu_files/Netmenu11.4.csv', encoding='latin-1')
Nov_4_Comm
# Out:
#       ScheduleBusinessUnitOid AscBusinessUnitName  ScheduleTimePeriodOid  \
# 0                       10679  Commons Production                     13
# 1                       10679  Commons Production                     13
# 2                       10679  Commons Production                     13
# 3                       10679  Commons Production                     13
# 4                       10679  Commons Production                     13
# ...                       ...                 ...                    ...
# 3939                    10679  Commons Production                  32727
# 3940                    10679  Commons Production                  32727
# 3941                    10679  Commons Production                  32727
# 3942                    10679  Commons Production                  32727
# 3943                    10679  Commons Production                  32727
#
#      AscTimePeriodName    ScheduleDate                      Name  \
# ...

# %%
for col in Nov_4_Comm.columns:
    print(col)
# Out:
# ScheduleBusinessUnitOid
# AscBusinessUnitName
# ScheduleTimePeriodOid
# AscTimePeriodName
# ScheduleDate
# Name
# AscCourseUseDefUofM
# AscCustomItemTypeOid
# AscForecastUofMName
# AscIsPreferredItem
# AscItemBizUnitOid
# AscItemKeyName
# AscItemMPGName
# AscItemMPGOid
# AscItemName
# AscItemPLU
# AscItemProductGroupName
# AscItemProductGroupOid
# AscItemType
# AscItemUPCCodes
# AscNutritionItemOidNonRecipe
# AscPreparedUofMName
# AscProductionImageURI
# AscProductionVideoURI
# AscServedUofMName
# AscServiceCourseName
# AscServiceCourseSequence
# AscServiceStationName
# AscServiceStationSort
# AscSrvMenuUOfMUPCCodes
# ExcludeFromServiceReports
# Identity
# IsLockedMBBItem
# IsMBBItem
# Oid
# PriceOverride
# ScalingRule
# ServiceCourseOid
# ServiceStationOid
# SSCalculatedQtyColumn
# SSForecastAmount
# SSForecastCost
# SSForecastUofMOid
# SSIAdvProd
# SSIAdvWithdrawal
# SSIDefaultAdvanceProduction
# SSIDefaultAdvanceWithdrawal
# SSIDefaultIsActive
# SSIDefaultMaximumBatch
# ...

# %%
Nov_4_Comm= Nov_4_Comm.drop_duplicates()

# %%
cpm_df_11_4 = Nov_4_Comm[['AscTimePeriodName','ScheduleDate', 'Name', 'SSServiceName','AscForecastUofMName', 'AscPreparedUofMName', 'AscServedUofMName', 'AscServiceCourseName', 'SSForecastAmount','SSForecastCost','SSPreparedAmount', 'SSPreparedCost', 'SSServedAmount','SSServedCost']]
cpm_df_11_4
# Out:
#      AscTimePeriodName    ScheduleDate                      Name  \
# 0            Breakfast  11/4/2019 0:00          Monday-Breakfast
# 5            Breakfast  11/4/2019 0:00          Monday-Breakfast
# 10           Breakfast  11/4/2019 0:00          Monday-Breakfast
# 11           Breakfast  11/4/2019 0:00          Monday-Breakfast
# 12           Breakfast  11/4/2019 0:00          Monday-Breakfast
# ...                ...             ...                       ...
# 3939   Daily Offerings  11/4/2019 0:00  Monday - Daily Offerings
# 3940   Daily Offerings  11/4/2019 0:00  Monday - Daily Offerings
# 3941   Daily Offerings  11/4/2019 0:00  Monday - Daily Offerings
# 3942   Daily Offerings  11/4/2019 0:00  Monday - Daily Offerings
# 3943   Daily Offerings  11/4/2019 0:00  Monday - Daily Offerings
#
#                   SSServiceName AscForecastUofMName AscPreparedUofMName  \
# 0            Frozen Blueberries       2 oz. portion       2 oz. portion
# ...
